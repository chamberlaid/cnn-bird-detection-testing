# %%
#colab only
from google.colab import drive
drive.mount('/content/drive')
# Out:
# test

# %%
#run on cmd if running locally
# !pip install ultralytics

# %%
#run code with exclamation marks in command prompt if not using google colab
from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display
display.clear_output()
# !yolo checks

# %%
#colab only
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11n.yaml")  # build a new model from YAML
model = YOLO("yolo11n.pt")  # load a pretrained model (recommended for training)
model = YOLO("yolo11n.yaml").load("yolo11n.pt")  # build from YAML and transfer weights

# Train the model
results = model.train(data="/content/drive/MyDrive/projects/computer-vision-testing/bird_detection/data_colab.yaml", epochs=100, imgsz=640)
